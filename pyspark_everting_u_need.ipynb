# %%
host="localhost"
user="root"
password="root"
db="college"

# this are cred from sql host connection

# %%
# !pip install pyspark
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ---------------------------------------- 0.0/455.4 MB ? eta -:--:--
#      -------------------------------------- 0.0/455.4 MB 435.7 kB/s eta 0:17:25
#      ---------------------------------------- 0.1/455.4 MB 1.4 MB/s eta 0:05:22
#      ---------------------------------------- 0.4/455.4 MB 2.7 MB/s eta 0:02:50
#      ---------------------------------------- 0.7/455.4 MB 3.9 MB/s eta 0:01:56
#      ---------------------------------------- 0.8/455.4 MB 4.2 MB/s eta 0:01:49
#      ---------------------------------------- 1.0/455.4 MB 3.6 MB/s eta 0:02:06
#      ---------------------------------------- 1.4/455.4 MB 4.4 MB/s eta 0:01:45
#      ---------------------------------------- 1.7/455.4 MB 4.6 MB/s eta 0:01:39
#      ---------------------------------------- 1.9/455.4 MB 4.8 MB/s eta 0:01:36
#      ---------------------------------------- 2.2/455.4 MB 4.8 MB/s eta 0:01:34
# ...
